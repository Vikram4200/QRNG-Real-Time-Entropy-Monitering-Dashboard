# %%
from qiskit import QuantumCircuit
qc = QuantumCircuit(1)
qc.x(0)
qc.draw(output='mpl')

# %%
from qiskit import QuantumCircuit
qc = QuantumCircuit(3)
qc.x(0)
qc.draw(output='mpl')

# %%
from qiskit import QuantumCircuit
qc = QuantumCircuit(3)
qc.x(0)
qc.y(1)
qc.z(2)

qc.draw(output='mpl')

# %%
from qiskit import QuantumCircuit
qc = QuantumCircuit(3)
qc.x(0)
qc.y(0)
qc.z(2)

qc.draw(output='mpl')

# %%
from qiskit import QuantumCircuit
qc = QuantumCircuit(3)
qc.h(1)
qc.x(2)
qc.y(1)
qc.z(0)

qc.draw(output='mpl')

# %%
from qiskit import QuantumCircuit
qc = QuantumCircuit(3)
qc.h(1)
qc.x(2)
qc.y(1)
qc.z(0)
qc.cx(1,0)

qc.draw(output='mpl')

# %% [markdown]
# mpl is a matplotlib,
# cx is a ckt

# %%
from qiskit import QuantumCircuit
qc = QuantumCircuit(3)
qc.h(1)
qc.x(2)
qc.y(1)
qc.z(0)
qc.cx(1,0)
qc.p(1,0)

qc.draw(output='mpl')

# %% [markdown]
# from qiskit import QuantumCircuit
# qc = QuantumCircuit(3)
# qc.h(1)
# qc.x(2)
# qc.y(1)
# qc.z(0)
# qc.cx(1,0)
# qc.p(1,0) // phasegate is 1 is theta and 0 is position
#
# qc.draw(output='mpl')

# %%
from qiskit import QuantumCircuit
qc = QuantumCircuit(3)
qc.h(1)
qc.x(2)
qc.y(1)
qc.z(0)
qc.cx(1,0)
qc.p(3.14,2)
qc.swap(0,1) # is a swap function

qc.draw(output='mpl')

# %%
from qiskit import QuantumCircuit
qc = QuantumCircuit(4)
qc.h(1)
qc.x(2)
qc.y(1)
qc.z(0)
qc.cx(1,0)
qc.p(3.14,2)
qc.swap(0,1)
qc.ccx(0,1,3) # control qubits
qc.draw(output='mpl')

# %%
# %matplotlib inline
from qiskit import QuantumCircuit, transpile # 
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt
# circuit program start from here
qc = QuantumCircuit(1)
qc.h(0)
qc.measure_all()
# simulation cmd
sim = AerSimulator()

compiled = transpile(qc,sim)
result = sim.run(compiled, shots=1024).result()
counts = result.get_counts()
# qc.x(2)
# qc.y(1)
# qc.z(0)
# qc.cx(1,0)
# qc.p(3.14,2)
# qc.swap(0,1)
# qc.ccx(0,1,3) # control qubits

#output
qc.draw(output='mpl')
print("Measurement counts : ",counts)
plot_histogram(counts)
plt.show()
# Out:
# Measurement counts :  {'0': 506, '1': 518}

# %%
# %matplotlib inline
from qiskit import QuantumCircuit, transpile # 
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt
# circuit program start from here
qc = QuantumCircuit(2)
qc.h(0)
qc.cx(1,0)
qc.measure_all()
# simulation cmd
sim = AerSimulator()

compiled = transpile(qc,sim)
result = sim.run(compiled, shots=1024).result()
counts = result.get_counts()
# qc.x(2)
# qc.y(1)
# qc.z(0)
# qc.cx(1,0)
# qc.p(3.14,2)
# qc.swap(0,1)
# qc.ccx(0,1,3) # control qubits

#output
qc.draw(output='mpl')
print("Measurement counts : ",counts)
plot_histogram(counts)
plt.show()
# Out:
# Measurement counts :  {'00': 505, '01': 519}

# %%
# %matplotlib inline
from qiskit import QuantumCircuit, transpile # 
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt
# circuit program start from here
qc = QuantumCircuit(3)
qc.h(0) # hadamart q is 0
qc.y(1)
qc.cx(0,2) #  all the quibut is 0 applyng slip the 0 to 1
qc.measure_all()
# simulation cmd
sim = AerSimulator()

compiled = transpile(qc,sim)
result = sim.run(compiled, shots=1024).result()
counts = result.get_counts()
# qc.x(2)
# qc.y(1)
# qc.z(0)
# qc.cx(1,0)
# qc.p(3.14,2)
# qc.swap(0,1)
# qc.ccx(0,1,3) # control qubits

#output
qc.draw(output='mpl')
print("Measurement counts : ",counts)
plot_histogram(counts)
plt.show()
# Out:
# Measurement counts :  {'111': 489, '010': 535}

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit

q = QuantumRegister(2,'q')
c = ClassicalRegister(2,'c')

qc = QuantumCircuit(q,c)

# %%
# %matplotlib inline
from qiskit import QuantumCircuit, transpile # 
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt
# circuit program start from here
qc = QuantumCircuit(3)
qc.h(0) # hadamart q is 0
qc.y(1)
qc.cx(0,2) #  all the quibut is 0 applyng slip the 0 to 1
qc.measure_all()
# simulation cmd
sim = AerSimulator()

compiled = transpile(qc,sim)
result = sim.run(compiled, shots=1024).result()
counts = result.get_counts()

qc.draw(output='mpl')
print("Measurement counts : ",counts)
plot_histogram(counts)
plt.show()
# Out:
# Measurement counts :  {'111': 494, '010': 530}

# %%
# %matplotlib inline
from qiskit import QuantumCircuit, transpile # 
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt
# circuit program start from here
qc = QuantumCircuit(3)
qc.h(0) # hadamart q is 0
qc.y(1)
qc.cx(0,2) #  all the quibut is 0 applyng slip the 0 to 1
qc.measure_all()
qc.delay(100,0)
# simulation cmd
sim = AerSimulator()

compiled = transpile(qc,sim)
result = sim.run(compiled, shots=1024).result()
counts = result.get_counts()

qc.draw(output='mpl')
print("Measurement counts : ",counts)
plot_histogram(counts)
plt.show()
# Out:
# Measurement counts :  {'111': 525, '010': 499}

# %%
# %matplotlib inline
from qiskit import QuantumCircuit, transpile # 
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt
from qiskit.quantum_info import Statevector  # state 
from qiskit.visualization import plot_bloch_multivector
# circuit program start from here
qc = QuantumCircuit(6) 
qc.h(0)
qc.h(1)
qc.h(2)
qc.h(3)
qc.h(4)
# qc.h(5)

# qc.ccx(0,1,2)
# state = Statevector.from_instruction(qc)
# plot_bloch_multivector(state)
qc.measure_all()
# simulation cmd
sim = AerSimulator()
compiled = transpile(qc,sim)
while True:
    
    result = sim.run(compiled, shots=1).result()
    counts = result.get_counts()

    b = list(counts.keys())[0]   #extract binary output
    d = int(b, 2)  # convert to binary to decimal


#output
    if  d <= 50 and d%2 == 0:
        # qc.draw(output='mpl')
        print("Random Binary Number:", b)
        print("random Decimal Number :", d)
        # print("Measurement counts : ",counts)
        # plot_histogram(counts)
        # plt.show()
        break

# print("Random Binary Number:", binary_number)
# print("random Decimal Number :", decimal_number)
# # print("Measurement counts : ",counts)
# plot_histogram(counts)
# Out:
# Random Binary Number: 001000
# random Decimal Number : 8

# %%
from qiskit import QuantumCircuit, transpile
from qiskit.visualization import plot_histogram
import qiskit_ibm_runtime
from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2 as Sampler

import matplotlib.pyplot as plt

QiskitRuntimeService.save_account(
    channel= "ibm_cloud", 
    token = "ZqA9A4K3lgOu15xvwDhYuNPbZmvBnPTPSgBdC4upeo9w",
    instance = "crn:v1:bluemix:public:quantum-computing:us-east:a/33a294d6130e4ee6b3cc3501110a3fad:222a82aa-6560-40b5-bf50-8c63982798ef::",
    overwrite = True
)

service = QiskitRuntimeService()
backend = service.least_busy(simulator = False)

print("Using backend:", backend.name)

# Create a bell state circuit

qc = QuantumCircuit(2)

qc.h(0)
qc.cx(0, 1)

qc.measure_all()

print(qc.draw())

transpiled_qc = transpile(qc, backend)

#create a sempler
sampler = Sampler(backend)


job = sampler.run([transpiled_qc], shots=1024)

print("\nJob Submitted successfully.")
print("Job ID:", job.job_id())

# get results
result = job.result()

pub_results = result[0]
counts = pub_results.data.meas.get_counts()

print("\nCounts:", counts)

plot_histogram(counts)
plt.show()
# Out:
# Using backend: ibm_marrakesh
#         ┌───┐      ░ ┌─┐
#    q_0: ┤ H ├──■───░─┤M├───
#         └───┘┌─┴─┐ ░ └╥┘┌─┐
#    q_1: ─────┤ X ├─░──╫─┤M├
#              └───┘ ░  ║ └╥┘
# meas: 2/══════════════╩══╩═
#                       0  1
#
# Job Submitted successfully.
# Job ID: d8fd0q1vjngc73apmgs0
#
# Counts: {'00': 506, '10': 29, '01': 8, '11': 481}

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

QiskitRuntimeService.delete_account()
# Out:
# True

# %%
from qiskit import QuantumCircuit, transpile
from qiskit.visualization import plot_histogram
import qiskit_ibm_runtime
from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2 as Sampler

import matplotlib.pyplot as plt

QiskitRuntimeService.save_account(
    channel= "ibm_cloud", 
    token = "ZqA9A4K3lgOu15xvwDhYuNPbZmvBnPTPSgBdC4upeo9w",
    instance = "crn:v1:bluemix:public:quantum-computing:us-east:a/33a294d6130e4ee6b3cc3501110a3fad:222a82aa-6560-40b5-bf50-8c63982798ef::",
    overwrite = True
)

service = QiskitRuntimeService()
backend = service.least_busy(simulator = False)

print("Using backend:", backend.name)

# Create a bell state circuit

qc = QuantumCircuit(3)
qc.h(0)
qc.h(1)
qc.h(2)

qc.measure_all()

print(qc.draw())

transpiled_qc = transpile(qc, backend)

#create a sempler
sampler = Sampler(backend)


job = sampler.run([transpiled_qc], shots=1024)

print("\nJob Submitted successfully.")
print("Job ID:", job.job_id())

# get results
result = job.result()

pub_results = result[0]
counts = pub_results.data.meas.get_counts()

print("\nCounts:", counts)

plot_histogram(counts)
plt.show()
# Out:
# Using backend: ibm_marrakesh
#         ┌───┐ ░ ┌─┐
#    q_0: ┤ H ├─░─┤M├──────
#         ├───┤ ░ └╥┘┌─┐
#    q_1: ┤ H ├─░──╫─┤M├───
#         ├───┤ ░  ║ └╥┘┌─┐
#    q_2: ┤ H ├─░──╫──╫─┤M├
#         └───┘ ░  ║  ║ └╥┘
# meas: 3/═════════╩══╩══╩═
#                  0  1  2
#
# Job Submitted successfully.
# Job ID: d8fd13ro3njc73f03i00
#
# Counts: {'100': 128, '111': 127, '010': 131, '110': 122, '001': 136, '011': 107, '101': 131, '000': 142}

# %%
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator
import matplotlib.pyplot as plt
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_histogram
import qiskit_ibm_runtime
from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2 as Sampler

import matplotlib.pyplot as plt

QiskitRuntimeService.save_account(
    channel= "ibm_cloud", 
    token = "ZqA9A4K3lgOu15xvwDhYuNPbZmvBnPTPSgBdC4upeo9w",
    instance = "crn:v1:bluemix:public:quantum-computing:us-east:a/33a294d6130e4ee6b3cc3501110a3fad:222a82aa-6560-40b5-bf50-8c63982798ef::",
    overwrite = True
)

service = QiskitRuntimeService()
backend = service.least_busy(simulator = False)

print("Using backend:", backend.name)

# Create a bell state circuit

qc = QuantumCircuit(3) # 3qubit
qc.h(0)
qc.h(1)
qc.h(2)

# qc.ccx(0,1,2)
# state = Statevector.from_instruction(qc)
# plot_bloch_multivector(state)
qc.measure_all()
# simulation cmd
sim = AerSimulator()

compiled = transpile(qc,sim)
result = sim.run(compiled, shots=1).result()
counts = result.get_counts()

binary_number = list(counts.keys())[0]   #extract binary output
decimal_number = int(binary_number, 2)  # convert to binary to decimal 

print("Random Binary Number:", binary_number)
print("random Decimal Number :", decimal_number)
print(qc.draw())

transpiled_qc = transpile(qc, backend)

#create a sempler
sampler = Sampler(backend)


job = sampler.run([transpiled_qc], shots=1024)

print("\nJob Submitted successfully.")
print("Job ID:", job.job_id())

# get results
result = job.result()

pub_results = result[0]
counts = pub_results.data.meas.get_counts()

print("\nCounts:", counts)

plot_histogram(counts)
plt.show()
# Out:
# Using backend: ibm_marrakesh
# Random Binary Number: 011
# random Decimal Number : 3
#         ┌───┐ ░ ┌─┐
#    q_0: ┤ H ├─░─┤M├──────
#         ├───┤ ░ └╥┘┌─┐
#    q_1: ┤ H ├─░──╫─┤M├───
#         ├───┤ ░  ║ └╥┘┌─┐
#    q_2: ┤ H ├─░──╫──╫─┤M├
#         └───┘ ░  ║  ║ └╥┘
# meas: 3/═════════╩══╩══╩═
#                  0  1  2
#
# Job Submitted successfully.
# Job ID: d8fd3h87jphs739m3050
#
# Counts: {'011': 111, '110': 142, '100': 138, '010': 130, '001': 119, '000': 137, '101': 127, '111': 120}

# %%
# %matplotlib inline
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator
import matplotlib.pyplot as plt
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_histogram
import qiskit_ibm_runtime
from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2 as Sampler

import matplotlib.pyplot as plt

QiskitRuntimeService.save_account(
    channel= "ibm_cloud", 
    token = "ZqA9A4K3lgOu15xvwDhYuNPbZmvBnPTPSgBdC4upeo9w",
    instance = "crn:v1:bluemix:public:quantum-computing:us-east:a/33a294d6130e4ee6b3cc3501110a3fad:222a82aa-6560-40b5-bf50-8c63982798ef::",
    overwrite = True
)

service = QiskitRuntimeService()
backend = service.least_busy(simulator = False)

print("Using backend:", backend.name)

# Create a bell state circuit

chars = "ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789@#$%&"
password = ""
for i in range(12):
    qc = QuantumCircuit(3) 
    qc.h(0) 
    qc.h(1)
    qc.h(2)
    
# qc.ccx(0,1,2)
# state = Statevector.from_instruction(qc)
# plot_bloch_multivector(state)
    qc.measure_all()
# simulation cmd
    sim = AerSimulator()
    compiled = transpile(qc,sim)

    
    result = sim.run(compiled, shots=1).result()
    counts = result.get_counts()

    b = list(counts.keys())[0]   #extract binary output
    d = int(b, 2)  # convert to binary to decimal


#output
    password += chars[(d * 9) % len(chars)]
    

    # qc.draw(output='mpl')

print(qc.draw())

transpiled_qc = transpile(qc, backend)

#create a sempler
sampler = Sampler(backend)


job = sampler.run([transpiled_qc], shots=1024)

print("\nJob Submitted successfully.")
print("Job ID:", job.job_id())

# get results
result = job.result()

pub_results = result[0]
counts = pub_results.data.meas.get_counts()

print("\nCounts:", counts)
print("password: ",password)
plot_histogram(counts)
plt.show()
# Out:
# Using backend: ibm_marrakesh
#         ┌───┐ ░ ┌─┐
#    q_0: ┤ H ├─░─┤M├──────
#         ├───┤ ░ └╥┘┌─┐
#    q_1: ┤ H ├─░──╫─┤M├───
#         ├───┤ ░  ║ └╥┘┌─┐
#    q_2: ┤ H ├─░──╫──╫─┤M├
#         └───┘ ░  ║  ║ └╥┘
# meas: 3/═════════╩══╩══╩═
#                  0  1  2
#
# Job Submitted successfully.
# Job ID: d8fd7307jphs739m34gg
#
# Counts: {'100': 116, '011': 134, '000': 109, '001': 116, '101': 121, '111': 136, '110': 147, '010': 145}
# password:  t##ktJbt2t#2

# %%
from qiskit import QuantumCircuit, transpile
from qiskit.visualization import plot_histogram
import qiskit_ibm_runtime
from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2 as Sampler

import matplotlib.pyplot as plt

QiskitRuntimeService.save_account(
    channel= "ibm_cloud", 
    token = "ZqA9A4K3lgOu15xvwDhYuNPbZmvBnPTPSgBdC4upeo9w",
    instance = "crn:v1:bluemix:public:quantum-computing:us-east:a/33a294d6130e4ee6b3cc3501110a3fad:222a82aa-6560-40b5-bf50-8c63982798ef::",
    overwrite = True
)

service = QiskitRuntimeService()
backend = service.least_busy(simulator = False)

print("Using backend:", backend.name)

# Create a bell state circuit

qc = QuantumCircuit(4)

qc.x(0)
qc.x(1)
qc.cx(0,2)
qc.cx(1,2)
qc.ccx(0,1,3)

qc.measure_all()

print(qc.draw())

transpiled_qc = transpile(qc, backend)

#create a sempler
sampler = Sampler(backend)


job = sampler.run([transpiled_qc], shots=1024)

print("\nJob Submitted successfully.")
print("Job ID:", job.job_id())

# get results
result = job.result()

pub_results = result[0]
counts = pub_results.data.meas.get_counts()

print("\nCounts:", counts)

plot_histogram(counts)
plt.show()
# Out:
# Using backend: ibm_marrakesh
#         ┌───┐                ░ ┌─┐
#    q_0: ┤ X ├──■─────────■───░─┤M├─────────
#         ├───┤  │         │   ░ └╥┘┌─┐
#    q_1: ┤ X ├──┼────■────■───░──╫─┤M├──────
#         └───┘┌─┴─┐┌─┴─┐  │   ░  ║ └╥┘┌─┐
#    q_2: ─────┤ X ├┤ X ├──┼───░──╫──╫─┤M├───
#              └───┘└───┘┌─┴─┐ ░  ║  ║ └╥┘┌─┐
#    q_3: ───────────────┤ X ├─░──╫──╫──╫─┤M├
#                        └───┘ ░  ║  ║  ║ └╥┘
# meas: 4/════════════════════════╩══╩══╩══╩═
#                                 0  1  2  3
#
# Job Submitted successfully.
# Job ID: d8fdfb1vjngc73apn1og
#
# Counts: {'1011': 942, '0011': 18, '1001': 19, '1010': 8, '1111': 12, '0010': 6, '0001': 9, '0110': 2, '0101': 6, '1000': 1, '0111': 1}

# %%
# %matplotlib inline
from qiskit import QuantumCircuit, transpile # 
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt
# circuit program start from here
qc = QuantumCircuit(4)
qc.x(0)
qc.x(1)
qc.cx(0,2)
qc.cx(1,2)
qc.ccx(0,1,3)
# qc.cx(1,0)
qc.measure_all()
# simulation cmd
sim = AerSimulator()

compiled = transpile(qc,sim)
result = sim.run(compiled, shots=1024).result()
counts = result.get_counts()


#output
qc.draw(output='mpl')
print("Measurement counts : ",counts)
plot_histogram(counts)
plt.show()
# Out:
# Measurement counts :  {'1011': 1024}

# %%
# %matplotlib inline
from qiskit import QuantumCircuit, transpile # 
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt
# circuit program start from here
qc = QuantumCircuit(1)
qc.h(0)
# qc.cx(1,0)
qc.measure_all()
# simulation cmd
sim = AerSimulator()

compiled = transpile(qc,sim)
result = sim.run(compiled, shots=1024).result()
counts = result.get_counts()
# qc.x(2)
# qc.y(1)
# qc.z(0)
# qc.cx(1,0)
# qc.p(3.14,2)
# qc.swap(0,1)
# qc.ccx(0,1,3) # control qubits

#output
qc.draw(output='mpl')
print("Measurement counts : ",counts)
plot_histogram(counts)
plt.show()
# Out:
# Measurement counts :  {'0': 516, '1': 508}
