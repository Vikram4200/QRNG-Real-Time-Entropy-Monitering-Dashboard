# %%
from qiskit import QuantumCircuit, transpile
from qiskit.visualization import plot_histogram
from qiskit_ibm_runtime import (QiskitRuntimeService,SamplerV2 as Sampler)

import matplotlib.pyplot as plt
QiskitRuntimeService.save_account(
    channel="ibm_cloud",
    token= "ZqA9A4K3lgOu15xvwDhYuNPbZmvBnPTPSgBdC4upeo9w",
    instance="crn:v1:bluemix:public:quantum-computing:us-east:a/33a294d6130e4ee6b3cc3501110a3fad:222a82aa-6560-40b5-bf50-8c63982798ef::",
    overwrite=True
)

# connect to ibm quantum service

service = QiskitRuntimeService()

# select least busy real backend
backend = service.least_busy(simulator = False)

print("Using Backend: ", backend.name)

#create bell state circuit

qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0,1)

# add measurement 
qc.measure_all()

#draw ckt

print(qc.draw())

#transpile for hardware
transpiled_qc = transpile(qc, backend)

#create samplear
sampler = Sampler(backend)

job = sampler.run([transpiled_qc], shots=1024)

print("\njob submitted succesfully")
print("job ID: ", job.job_id())

# get result

result = job.result()

#extract counts
pub_result= result[0]

counts = pub_result.data.meas.get_counts()

print("\nCounts:", counts)

plot_histogram(counts)
plt.show()
# Out:
# Using Backend:  ibm_marrakesh
#         ┌───┐      ░ ┌─┐
#    q_0: ┤ H ├──■───░─┤M├───
#         └───┘┌─┴─┐ ░ └╥┘┌─┐
#    q_1: ─────┤ X ├─░──╫─┤M├
#              └───┘ ░  ║ └╥┘
# meas: 2/══════════════╩══╩═
#                       0  1
#
# job submitted succesfully
# job ID:  d8eomhro3njc73ev54v0
#
# Counts: {'00': 504, '11': 494, '01': 16, '10': 10}

# %%
from qiskit import QuantumCircuit, transpile
from qiskit.visualization import plot_histogram
import qiskit_ibm_runtime
from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2 as Sampler

import matplotlib.pyplot as plt

QiskitRuntimeService.save_account (
    channel= "ibm_quantum_platform", 
    token = "ApiKey-aac544d2-b24b-4bb5-8f64-6037ec3bd281",
    instance = "crn:v1:bluemix:public:quantum-computing:us-east:a/33a294d6130e4ee6b3cc3501110a3fad:222a82aa-6560-40b5-bf50-8c63982798ef::",
    overwrite = True
)

service = QiskitRuntimeService()
backend = service.least_busy(simulator = False)

print("Using backend:", backend.name)

# Create a bell state circuit

qc = QuantumCircuit(2)

qc.h(0)
qc.cx(0, 1)

qc.measure_all()

print(qc.draw())

transpiled_qc = transpile(qc, backend)

sampler = Sampler(backend)


job = sampler.run([transpiled_qc], shots=1024)

print("\nJob Submitted successfully.")
print("Job ID:", job.job_id())

result = job.result()

pub_results = result[0]
counts = pub_results.data.meas.get_counts()

print("\nCounts:", counts)

plot_histogram(counts)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\qiskit_ibm_runtime\accounts\account.py:351, in CloudAccount.list_instances(self)
#     350 try:
# --> 351     result = client.search(
#     352         query="service_name:quantum-computing",
#     353         fields=[
#     354             "crn",
#     355             "service_plan_unique_id",
#     356             "name",
#     357             "doc",
#     358             "tags",
#     359         ],
#     360         search_cursor=search_cursor,
#     361         limit=100,
#     362         verify=self.verify,
#     363         **proxies_kwargs,
#     364     ).get_result()
#     365 except Exception as ex:
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\ibm_platform_services\global_search_v2.py:228, in GlobalSearchV2.search(self, query, fields, search_cursor, x_request_id, x_correlation_id, account_id, limit, timeout, sort, is_deleted, is_reclaimed, impersonate_user, can_tag, is_project_resource, **kwargs)
#     227 url = '/v3/resources/search'
# --> 228 request = self.prepare_request(
#     229     method='POST',
#     230     url=url,
#     231     headers=headers,
#     232     params=params,
#     233     data=data,
#     234 )
#     236 response = self.send(request, **kwargs)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\ibm_cloud_sdk_core\base_service.py:441, in BaseService.prepare_request(self, method, url, headers, params, data, files, **kwargs)
#     439 request['data'] = data
# --> 441 self.authenticator.authenticate(request)
#     443 # Compress the request body if applicable
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\ibm_cloud_sdk_core\authenticators\iam_request_based_authenticator.py:64, in IAMRequestBasedAuthenticator.authenticate(self, req)
#      63 headers = req.get('headers')
# ---> 64 bearer_token = self.token_manager.get_token()
#      65 headers['Authorization'] = 'Bearer {0}'.format(bearer_token)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\ibm_cloud_sdk_core\token_managers\token_manager.py:82, in TokenManager.get_token(self)
#      81     logger.debug('Performing synchronous token fetch')
# ---> 82     self.paced_request_token()
#      84 if self._token_needs_refresh():
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\ibm_cloud_sdk_core\token_managers\token_manager.py:141, in TokenManager.paced_request_token(self)
#     140 if not request_active:
# --> 141     token_response = self.request_token()
#     142     self._save_token_info(token_response)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\ibm_cloud_sdk_core\token_managers\iam_request_based_token_manager.py:127, in IAMRequestBasedTokenManager.request_token(self)
#     126 logger.debug('Invoking IAM get_token operation: %s', request_url)
# --> 127 response = self._request(
#     128     method='POST',
#     129     url=request_url,
#     130     headers=request_headers,
#     131     data=data,
#     132     auth_tuple=auth_tuple,
#     133     proxies=self.proxies,
#     134 )
#     135 logger.debug('Returned from IAM get_token operation')
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\ibm_cloud_sdk_core\token_managers\jwt_token_manager.py:91, in JWTTokenManager._request(self, method, url, headers, params, data, auth_tuple, **kwargs)
#      89     return response.json()
# ---> 91 raise ApiException(response.status_code, http_response=response)
#
# ApiException: Error: Provided API key could not be found., Status code: 400
#
# The above exception was the direct cause of the following exception:
#
# InvalidAccountError                       Traceback (most recent call last)
# Cell In[4], line 15
#      11     instance = "crn:v1:bluemix:public:quantum-computing:us-east:a/33a294d6130e4ee6b3cc3501110a3fad:222a82aa-6560-40b5-bf50-8c63982798ef::",
#      12     overwrite = True
#      13 )
#      14
# ---> 15 service = QiskitRuntimeService()
#      16 backend = service.least_busy(simulator = False)
#      17
#      18 print("Using backend:", backend.name)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\qiskit_ibm_runtime\qiskit_runtime_service.py:249, in QiskitRuntimeService.__init__(self, channel, token, url, filename, name, instance, proxies, verify, private_endpoint, url_resolver, region, plans_preference, tags)
#     247 self._tags = tags or self._account.tags
#     248 if self._account.instance:
# --> 249     if self._account.instance not in [inst["crn"] for inst in self.instances()]:
#     250         raise IBMInputValueError(
#     251             "The given API token is associated with an account that does not have access "
#     252             f"to the instance {self._account.instance}. "
#     253             "To use this instance, use an API token generated from the account "
#     254             "with this instance available."
#     255         )
#     256     self._default_instance = True
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\qiskit_ibm_runtime\qiskit_runtime_service.py:1356, in QiskitRuntimeService.instances(self)
#    1347 """Return a list of instances available for the active account.
#    1348
#    1349 Return a list that contains a series of dictionaries with the following instance
#    (...)   1353     A list with instances available for the active account.
#    1354 """
#    1355 if not self._all_instances:
# -> 1356     self._all_instances = self._account.list_instances()
#    1357 return self._all_instances
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\qiskit_ibm_runtime\accounts\account.py:366, in CloudAccount.list_instances(self)
#     351     result = client.search(
#     352         query="service_name:quantum-computing",
#     353         fields=[
#    (...)    363         **proxies_kwargs,
#     364     ).get_result()
#     365 except Exception as ex:
# --> 366     raise InvalidAccountError(
#     367         "Unable to retrieve instances. "
#     368         "Please check that you are using a valid API token."
#     369     ) from ex
#     370 crns = []
#     371 items = result.get("items", [])
#
# InvalidAccountError: 'Unable to retrieve instances. Please check that you are using a valid API token.'

# %%
from qiskit import QuantumCircuit, transpile
from qiskit.visualization import plot_histogram
import qiskit_ibm_runtime
from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2 as Sampler

import matplotlib.pyplot as plt

QiskitRuntimeService.save_account(
    channel= "ibm_cloud", 
    token = "ZqA9A4K3lgOu15xvwDhYuNPbZmvBnPTPSgBdC4upeo9w",
    instance = "crn:v1:bluemix:public:quantum-computing:us-east:a/33a294d6130e4ee6b3cc3501110a3fad:222a82aa-6560-40b5-bf50-8c63982798ef::",
    overwrite = True
)

service = QiskitRuntimeService()
backend = service.least_busy(simulator = False)

print("Using backend:", backend.name)

# Create a bell state circuit

qc = QuantumCircuit(4)

qc.x(0)
qc.x(1)
qc.ccx(0,1,2)
qc.cx(1,2)
qc.cccx(0,1,2,3)

qc.measure_all()

print(qc.draw())

transpiled_qc = transpile(qc, backend)

#create a sempler
sampler = Sampler(backend)


job = sampler.run([transpiled_qc], shots=1024)

print("\nJob Submitted successfully.")
print("Job ID:", job.job_id())

# get results
result = job.result()

pub_results = result[0]
counts = pub_results.data.meas.get_counts()

print("\nCounts:", counts)

plot_histogram(counts)
plt.show()

# %%
from qiskit import QuantumCircuit, transpile
from qiskit.visualization import plot_histogram
import qiskit_ibm_runtime
from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2 as Sampler

import matplotlib.pyplot as plt

QiskitRuntimeService.save_account(
    channel= "ibm_cloud", 
    token = "ZqA9A4K3lgOu15xvwDhYuNPbZmvBnPTPSgBdC4upeo9w",
    instance = "crn:v1:bluemix:public:quantum-computing:us-east:a/33a294d6130e4ee6b3cc3501110a3fad:222a82aa-6560-40b5-bf50-8c63982798ef::",
    overwrite = True
)

service = QiskitRuntimeService()
backend = service.least_busy(simulator = False)

print("Using backend:", backend.name)

# Create a bell state circuit

qc = QuantumCircuit(4)

qc.x(0)
qc.x(1)
qc.cx(0,2)
qc.cx(1,2)
qc.ccx(0,1,3)

qc.measure_all()

print(qc.draw())

transpiled_qc = transpile(qc, backend)

#create a sempler
sampler = Sampler(backend)


job = sampler.run([transpiled_qc], shots=1024)

print("\nJob Submitted successfully.")
print("Job ID:", job.job_id())

# get results
result = job.result()

pub_results = result[0]
counts = pub_results.data.meas.get_counts()

print("\nCounts:", counts)

plot_histogram(counts)
plt.show()
